# %% [markdown]
# # Pārraudzītā mašīnmācīšanās — Mobilie tālruņi
# **Datu kopa:** `mobile_phones_2000.csv`
#
# Šis notebook demonstrē pilnu klasifikācijas caurplūsmu, lai prognozētu **Brand** pēc tālruņa tehniskajām specifikācijām.
# *Versija ģenerēta:* 2025-05-10 14:14

# %% [markdown]
# ## 1 Daļa Importi un iestatījumi

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import (classification_report, confusion_matrix,
                             ConfusionMatrixDisplay, accuracy_score)
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans


# %matplotlib inline
sns.set_theme(style="ticks")

# %% [markdown]
# ## Datu un faktoru vērtību vizualizācija

# %% [markdown]
# ### Vērtību attēlojums

# %%
import pandas as pd, numpy as np, seaborn as sns, matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline
sns.set_theme(style="ticks")

df = pd.read_csv("mobile_phones_2000.csv")
numeric_cols = df.select_dtypes(include=['int64','float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()
print("Numeric:", numeric_cols, "\nCategorical:", categorical_cols)
# Out:
# Numeric: ['Price (USD)', 'Rating', 'Refresh Rate (Hz)', 'Screen Size (inches)', 'RAM (GB)', 'Storage (GB)']
# Categorical: ['Brand', 'Model', 'Selling Platform', 'Processor', 'Camera Setup']

# %%
# ── Kategorisko atribūtu tipa maiņa uz "category" ────────────────────────
#  (ievietojiet uzreiz pēc CSV ielādes / bibliotēku importēšanas)

# 1) izveidojam kopiju, lai nepārrakstītu oriģinālo df
datu_kopa = df.copy()

# 2) kolonnas, kurām LOĢISKI ir kategoriskas vērtības
kat_atrib = ['Brand',    # ražotājs
             'Model',    # konkrēts modelis
             'Selling Platform',  # Amazon / eBay / ...
             'Processor',         # Snapdragon / Exynos …
             'Camera Setup']      # Dual / Triple / …

# 3) katrai kolonnai pielietojam astype('category')
for kol in kat_atrib:
    if kol in datu_kopa.columns:          # drošības pārbaude, vai kolonna vispār eksistē
        datu_kopa[kol] = datu_kopa[kol].astype('category')

# 4) pārbaudām rezultātu
print(datu_kopa[kat_atrib].dtypes)        # jāpieredz 'category'
print(datu_kopa.head(7))                  # pirmās 7 rindas
# Out:
# Brand               category
# Model               category
# Selling Platform    category
# Processor           category
# Camera Setup        category
# dtype: object
#      Brand               Model  Price (USD)  Selling Platform  Rating  \
# 0  OnePlus       Narzo Edge 16      1286.64          Best Buy     3.5
# 1     Sony        Pixel Max 24       728.52              eBay     4.6
# 2  Samsung        Reno Plus 23      1086.68    Official Store     3.4
# 3    Apple  Redmi Note Mini 16      1158.78    Official Store     3.5
# 4     Vivo    P Series Edge 13      1656.05  Reliance Digital     4.9
# 5     Vivo      P Series 5G 19       390.46          Best Buy     4.4
# 6     Sony   Galaxy S Ultra 22      1172.46          Best Buy     3.2
#
#    Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# 0                165                   7.2        16           128
# 1                 90                   6.1         4            64
# 2                 60                   6.2        12            64
# 3                120                   7.1         6           128
# 4                165                   6.1         8           512
# 5                165                   6.5        12           512
# 6                120                   6.5         8           256
#
#              Processor        Camera Setup
# 0  Snapdragon 8+ Gen 1   12MP + 16MP + 5MP
# 1        Dimensity 920    48MP + 8MP + 5MP
# 2          Exynos 2200  200MP + 12MP + 8MP
# 3           A16 Bionic   50MP + 50MP + 2MP
# 4            Helio G99   64MP + 50MP + 8MP
# 5        Dimensity 920   48MP + 50MP + 8MP
# 6        Dimensity 920    12MP + 8MP + 2MP

# %% [markdown]
# ### Datu tipu salāgošana

# %% [markdown]
# Šajā sadaļā atkārtojam soļus, kas demonstrēti pingvīnu piemērā:
# 1. kategorisko atribūtu pārvēršana par `category` tipu,
# 2. jaunu *_cat* kolonu veidošana ar `.cat.codes`,
# 3. trūkstošo vērtību aizvietošana skaitliskajos atribūtos,
# 4. anomālo/«nezināmo» kategoriju apstrāde (ja tādas ir),
# 5. min‑max normalizācija četrām skaitliskajām pazīmēm, lai tās būtu salīdzināmas.

# %%
import pandas as pd, numpy as np
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv("mobile_phones_2000.csv")
print("Oriģinālie dati (pirmās 5 rindas):")
display(df.head())
print("\nKolonnu tipi:")
print(df.dtypes)
# Out:
# Oriģinālie dati (pirmās 5 rindas):
#      Brand               Model  Price (USD)  Selling Platform  Rating  \
# 0  OnePlus       Narzo Edge 16      1286.64          Best Buy     3.5
# 1     Sony        Pixel Max 24       728.52              eBay     4.6
# 2  Samsung        Reno Plus 23      1086.68    Official Store     3.4
# 3    Apple  Redmi Note Mini 16      1158.78    Official Store     3.5
# 4     Vivo    P Series Edge 13      1656.05  Reliance Digital     4.9
#
#    Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# 0                165                   7.2        16           128
# 1                 90                   6.1         4            64
# 2                 60                   6.2        12            64
# 3                120                   7.1         6           128
# 4                165                   6.1         8           512
#
#              Processor        Camera Setup
# 0  Snapdragon 8+ Gen 1   12MP + 16MP + 5MP
# 1        Dimensity 920    48MP + 8MP + 5MP
# 2          Exynos 2200  200MP + 12MP + 8MP
# 3           A16 Bionic   50MP + 50MP + 2MP
# 4            Helio G99   64MP + 50MP + 8MP
# Kolonnu tipi:
# Brand                    object
# Model                    object
# Price (USD)             float64
# Selling Platform         object
# Rating                  float64
# Refresh Rate (Hz)         int64
# Screen Size (inches)    float64
# RAM (GB)                  int64
# Storage (GB)              int64
# Processor                object
# Camera Setup             object
# dtype: object

# %% [markdown]
# ## Kategorisko atribūtu tipa maiņa uz `category`

# %%
cat_cols = df.select_dtypes(include=['object']).columns.tolist()
for col in cat_cols:
    df[col] = df[col].astype('category')

print("Pēc pārveides — dtypes:")
print(df.dtypes)
display(df.head())
# Out:
# Pēc pārveides — dtypes:
# Brand                   category
# Model                   category
# Price (USD)              float64
# Selling Platform        category
# Rating                   float64
# Refresh Rate (Hz)          int64
# Screen Size (inches)     float64
# RAM (GB)                   int64
# Storage (GB)               int64
# Processor               category
# Camera Setup            category
# dtype: object
#      Brand               Model  Price (USD)  Selling Platform  Rating  \
# 0  OnePlus       Narzo Edge 16      1286.64          Best Buy     3.5
# 1     Sony        Pixel Max 24       728.52              eBay     4.6
# 2  Samsung        Reno Plus 23      1086.68    Official Store     3.4
# 3    Apple  Redmi Note Mini 16      1158.78    Official Store     3.5
# 4     Vivo    P Series Edge 13      1656.05  Reliance Digital     4.9
#
#    Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# 0                165                   7.2        16           128
# 1                 90                   6.1         4            64
# 2                 60                   6.2        12            64
# 3                120                   7.1         6           128
# 4                165                   6.1         8           512
#
#              Processor        Camera Setup
# 0  Snapdragon 8+ Gen 1   12MP + 16MP + 5MP
# 1        Dimensity 920    48MP + 8MP + 5MP
# 2          Exynos 2200  200MP + 12MP + 8MP
# 3           A16 Bionic   50MP + 50MP + 2MP
# 4            Helio G99   64MP + 50MP + 8MP

# %% [markdown]
# ## *_cat* kolonu izveide ar `.cat.codes`

# %%
for col in cat_cols:
    df[f"{col}_cat"] = df[col].cat.codes
print(df[[f"{col}_cat" for col in cat_cols]].head())
print("\nAtjauninātie dtypes:")
print(df.dtypes)
# Out:
#    Brand_cat  Model_cat  Selling Platform_cat  Processor_cat  Camera Setup_cat
# 0          5        342                     2              9                16
# 1          9        672                     7              4                46
# 2          8        895                     4              5                26
# 3          0        774                     4              1                54
# 4         10        546                     5              6                68
#
# Atjauninātie dtypes:
# Brand                   category
# Model                   category
# Price (USD)              float64
# Selling Platform        category
# Rating                   float64
# Refresh Rate (Hz)          int64
# Screen Size (inches)     float64
# RAM (GB)                   int64
# Storage (GB)               int64
# Processor               category
# Camera Setup            category
# Brand_cat                   int8
# Model_cat                  int16
# Selling Platform_cat        int8
# Processor_cat               int8
# Camera Setup_cat            int8
# dtype: object

# %% [markdown]
# ## Aprakstošā statistika un info

# %%
numeric_and_encoded = ['Price (USD)', 'Rating', 'Refresh Rate (Hz)', 'Screen Size (inches)',
                       'RAM (GB)', 'Storage (GB)'] + [f"{c}_cat" for c in cat_cols]

print(df[numeric_and_encoded].describe())
print("\nDataFrame info:")
print(df[numeric_and_encoded].info())
# Out:
#        Price (USD)      Rating  Refresh Rate (Hz)  Screen Size (inches)  \
# count  2000.000000  2000.00000        2000.000000           2000.000000
# mean   1085.496980     3.99005         116.086500              6.268250
# std     526.886705     0.57630          37.199596              0.734974
# min     151.930000     3.00000          60.000000              5.000000
# 25%     644.187500     3.50000          90.000000              5.600000
# 50%    1081.455000     4.00000         120.000000              6.300000
# 75%    1546.532500     4.50000         144.000000              6.900000
# max    1999.260000     5.00000         165.000000              7.500000
#
#           RAM (GB)  Storage (GB)    Brand_cat    Model_cat  \
# count  2000.000000   2000.000000  2000.000000  2000.000000
# mean      9.171000    378.304000     5.483000   613.359000
# std       4.400505    339.345696     3.472858   357.268508
# min       4.000000     64.000000     0.000000     0.000000
# 25%       6.000000    128.000000     2.000000   300.000000
# 50%       8.000000    256.000000     6.000000   617.000000
# 75%      12.000000    512.000000     8.000000   918.250000
# max      16.000000   1024.000000    11.000000  1237.000000
#
#        Selling Platform_cat  Processor_cat  Camera Setup_cat
# count           2000.000000    2000.000000       2000.000000
# mean               3.502000       5.263000         35.532000
# std                2.300139       2.574324         20.947395
# min                0.000000       0.000000          0.000000
# 25%                1.000000       4.000000         18.000000
# 50%                4.000000       6.000000         36.000000
# 75%                6.000000       6.000000         54.000000
# max                7.000000      11.000000         71.000000
#
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Price (USD)           2000 non-null   float64
#  1   Rating                2000 non-null   float64
#  2   Refresh Rate (Hz)     2000 non-null   int64
#  3   Screen Size (inches)  2000 non-null   float64
#  4   RAM (GB)              2000 non-null   int64
#  5   Storage (GB)          2000 non-null   int64
#  6   Brand_cat             2000 non-null   int8
#  7   Model_cat             2000 non-null   int16
#  8   Selling Platform_cat  2000 non-null   int8
#  9   Processor_cat         2000 non-null   int8
#  10  Camera Setup_cat      2000 non-null   int8
# dtypes: float64(3), int16(1), int64(3), int8(4)
# memory usage: 105.6 KB
# None

# %% [markdown]
# ### Trūkstošo vērtību aizvietošana

# %%
work_df = df.copy()
num_cols = ['Price (USD)', 'Rating', 'Refresh Rate (Hz)', 'Screen Size (inches)',
            'RAM (GB)', 'Storage (GB)']
for col in num_cols:
    work_df[col] = work_df[col].fillna(work_df[col].mean())

print("Pārbaude, vai skaitliskajos atribūtos vairs nav NaN:")
print(work_df[num_cols].isna().sum())
# Out:
# Pārbaude, vai skaitliskajos atribūtos vairs nav NaN:
# Price (USD)             0
# Rating                  0
# Refresh Rate (Hz)       0
# Screen Size (inches)    0
# RAM (GB)                0
# Storage (GB)            0
# dtype: int64

# %% [markdown]
# ### «Nezināmo» kategoriju apzīmēšana (ja `-1` kods)

# %%
for col in cat_cols:
    code_col = f"{col}_cat"
    unknown_count = (work_df[code_col] == -1).sum()
    if unknown_count:
        print(f"{col}: {unknown_count} nezināmu vērtību → aizvietojam ar 0")
        work_df[code_col] = work_df[code_col].mask(work_df[code_col] == -1, 0)

# %% [markdown]
# ## Min‑max normalizācija (piemēram, Price / RAM / Storage / Rating)

# %%
darb_df_norm = df.copy()
# ―― Min–max normalizācija (0 … 1) ――
skaitliskie = ['Price (USD)',
               'RAM (GB)',
               'Storage (GB)',
               'Rating']

skaitliskie = df.select_dtypes(include=['number']).columns


for kol in skaitliskie:
    min_v = darb_df_norm[kol].min()
    max_v = darb_df_norm[kol].max()
    darb_df_norm[kol] = (darb_df_norm[kol] - min_v) / (max_v - min_v)

print(df.columns.tolist())
print(darb_df_norm[skaitliskie].describe())
# Out:
# ['Brand', 'Model', 'Price (USD)', 'Selling Platform', 'Rating', 'Refresh Rate (Hz)', 'Screen Size (inches)', 'RAM (GB)', 'Storage (GB)', 'Processor', 'Camera Setup', 'Brand_cat', 'Model_cat', 'Selling Platform_cat', 'Processor_cat', 'Camera Setup_cat']
#        Price (USD)       Rating  Refresh Rate (Hz)  Screen Size (inches)  \
# count  2000.000000  2000.000000        2000.000000            2000.00000
# mean      0.505360     0.495025           0.534157               0.50730
# std       0.285215     0.288150           0.354282               0.29399
# min       0.000000     0.000000           0.000000               0.00000
# 25%       0.266470     0.250000           0.285714               0.24000
# 50%       0.503172     0.500000           0.571429               0.52000
# 75%       0.754929     0.750000           0.800000               0.76000
# max       1.000000     1.000000           1.000000               1.00000
#
#           RAM (GB)  Storage (GB)    Brand_cat    Model_cat  \
# count  2000.000000   2000.000000  2000.000000  2000.000000
# mean      0.430917      0.327400     0.498455     0.495844
# std       0.366709      0.353485     0.315714     0.288819
# min       0.000000      0.000000     0.000000     0.000000
# 25%       0.166667      0.066667     0.181818     0.242522
# 50%       0.333333      0.200000     0.545455     0.498787
# 75%       0.666667      0.466667     0.727273     0.742320
# max       1.000000      1.000000     1.000000     1.000000
#
#        Selling Platform_cat  Processor_cat  Camera Setup_cat
# count           2000.000000    2000.000000       2000.000000
# mean               0.500286       0.478455          0.500451
# std                0.328591       0.234029          0.295034
# min                0.000000       0.000000          0.000000
# 25%                0.142857       0.363636          0.253521
# 50%                0.571429       0.545455          0.507042
# 75%                0.857143       0.545455          0.760563
# max                1.000000       1.000000          1.000000

# %% [markdown]
# ## Sagatavotie dati gatavi turpmākajai analīzei

# %%
display(work_df.head())
# Out:
#      Brand               Model  Price (USD)  Selling Platform  Rating  \
# 0  OnePlus       Narzo Edge 16      1286.64          Best Buy     3.5
# 1     Sony        Pixel Max 24       728.52              eBay     4.6
# 2  Samsung        Reno Plus 23      1086.68    Official Store     3.4
# 3    Apple  Redmi Note Mini 16      1158.78    Official Store     3.5
# 4     Vivo    P Series Edge 13      1656.05  Reliance Digital     4.9
#
#    Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# 0                165                   7.2        16           128
# 1                 90                   6.1         4            64
# 2                 60                   6.2        12            64
# 3                120                   7.1         6           128
# 4                165                   6.1         8           512
#
#              Processor        Camera Setup  Brand_cat  Model_cat  \
# 0  Snapdragon 8+ Gen 1   12MP + 16MP + 5MP          5        342
# 1        Dimensity 920    48MP + 8MP + 5MP          9        672
# 2          Exynos 2200  200MP + 12MP + 8MP          8        895
# 3           A16 Bionic   50MP + 50MP + 2MP          0        774
# 4            Helio G99   64MP + 50MP + 8MP         10        546
#
#    Selling Platform_cat  Processor_cat  Camera Setup_cat
# 0                     2              9                16
# 1                     7              4                46
# 2                     4              5                26
# 3                     4              1                54
# 4                     5              6                68

# %% [markdown]
# Datu un faktoru vērtību vizualizācija
# ---

# %% [markdown]
# ### Vērtību attēlojums

# %%
# --------------------------------------------
# "Lasāms" line-plot skaitliskajiem atribūtiem
# --------------------------------------------
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np

numeric_cols = ['Price (USD)', 'Rating', 'Refresh Rate (Hz)',
                'Screen Size (inches)', 'RAM (GB)', 'Storage (GB)']

# Normalizē vērtības 0-1
scaler  = MinMaxScaler()
norm_df = pd.DataFrame(scaler.fit_transform(df[numeric_cols]),
                       columns=numeric_cols)

# --- 1) retinām punktus ---
N_total   = len(norm_df)
target_n  = 300                           # cik punktus gribam uz ekrāna
step      = max(1, N_total // target_n)   # piem. 2000 // 300 ≈ 7
subsample = norm_df.iloc[::step, :].reset_index(drop=True)

# --- 2) izvēles kārtā – izlīdzinām (rolling mean) ---
window = 3                                # var palielināt, ja grib gludāku
smooth  = subsample.rolling(window, center=True).mean().fillna(subsample)

# --- 3) zīmējam ---
plt.figure(figsize=(20, 8))
colors = plt.cm.tab10.colors
for i, col in enumerate(numeric_cols):
    plt.plot(smooth.index, smooth[col],
             label=col,
             color=colors[i % len(colors)],
             linewidth=1.5, alpha=0.7)

plt.title('Normalizēto skaitlisko atribūtu vērtības (retināti dati)', fontsize=15)
plt.xlabel('Ieraksta indekss (retināts)'); plt.ylabel('Vērtība (0–1)')
plt.ylim(-0.05, 1.05)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Histogrammu analīze

# %%
hist_df = df.copy()
for col in categorical_cols:
    hist_df[col + "_cat"] = pd.Categorical(hist_df[col]).codes
hist_df = hist_df.drop(columns=categorical_cols)

hist_df.hist(figsize=(14,10), bins=30)
plt.suptitle("Datu kopas atribūtu histogrammas", y=1.02, fontsize=16)
plt.tight_layout(); plt.show()

# %% [markdown]
# ### Izkliedes diagrammu analīze (Atribūtu savstarpējie sadalījumi)

# %%
# 1. atlasām piecus populārākos zīmolus
top5 = df['Brand'].value_counts().nlargest(5).index

# 2. veidojam kopiju, lai oriģinālo DataFrame neatkarītu
pair_df = df.copy()

# 3. ja ‘Brand’ jau ir kategorisks, pievienojam jaunu kategoriju “Other”,
#    lai vēlāk nerastos kļūda, rakstot vērtību, kas nav kategoriju sarakstā
if pair_df['Brand'].dtype.name == 'category' and 'Other' not in pair_df['Brand'].cat.categories:
    pair_df['Brand'] = pair_df['Brand'].cat.add_categories('Other')

# 4. jaunā kolonna zīmējumu iekrāsošanai — TOP-5 vai “Other”
pair_df['Brand_top'] = pair_df['Brand'].where(pair_df['Brand'].isin(top5), 'Other')

# 5. izveidojam pāru (pairplot) grafiku tikai skaitliskajām kolonnām
sns.pairplot(pair_df,
             hue='Brand_top',
             vars=numeric_cols,          # skaitliskās pazīmes
             palette='muted',
             height=2.3,
             plot_kws=dict(alpha=.6, s=40, edgecolor='k', linewidth=.3))

plt.suptitle("Faktoru savstarpējās attiecības — TOP 5 zīmoli", y=1.02,
             fontsize=18, color='navy')
plt.show()

# %% [markdown]
# ### Atribūtu savstarpējā korelācija

# %%
corr = df[numeric_cols].corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, vmin=-1, vmax=1, cmap="coolwarm", square=True)
plt.title("Skaitlisko atribūtu korelācijas matrica")
plt.show()

# %% [markdown]
# 2 Daļa K-vidējo algoritms
# ---

# %%
# ─── ВСТАВИТЬ прямо перед циклом for k in range(2, 9): ──────────────────
cluster_cols = ['Price (USD)', 'RAM (GB)', 'Storage (GB)']   # любые 2-3 числовых
X_clust = df[cluster_cols].values
# ─────────────────────────────────────────────────────────────────────────

# %%
X_clust = df[cluster_cols].values
sil={}
for k in range(2,9):
    sil[k] = silhouette_score(X_clust, KMeans(n_clusters=k, n_init=10, random_state=42).fit_predict(X_clust))
best_k = max(sil, key=sil.get)
plt.figure(figsize=(4,4))
plt.plot(list(sil.keys()), list(sil.values()), marker='o')
plt.title('Silueta koeficienti')
plt.xlabel('Klasteru skaits'); plt.ylabel('Silhouette'); plt.show()
print("Labākais k:", best_k, "| Silhouette:", sil[best_k])
# Out:
# Labākais k: 3 | Silhouette: 0.48540035368080336

# %% [markdown]
# *Secinājums*: Silueta koeficients pakāpeniski **samazinās**, norādot, ka datu kopā nav ļoti izteiktu, stingri atdalītu grupu; tomēr **k = {{best_k}}** dod relatīvi augstāko vērtību, ko izmantojam turpmāk.

# %% [markdown]
# ### 2.1 — Klasteru izvietojums pazīmju plaknēs

# %%
# ─── один раз в начале ноутбука (после import numpy as np) ──────────────
def jitter(arr, width=0.15, seed=42):
    """Случайный «шум» для дискретных осей."""
    rng = np.random.default_rng(seed)
    return arr + (rng.random(len(arr)) - 0.5) * width
# ─────────────────────────────────────────────────────────────────────────

# %%
kmeans = KMeans(n_clusters=best_k, n_init=10, random_state=42).fit(X_clust)
labels = kmeans.labels_
cent   = kmeans.cluster_centers_

pairs = [('Price (USD)', 'RAM (GB)'),
         ('Price (USD)', 'Storage (GB)'),
         ('RAM (GB)',    'Storage (GB)')]

fig, axes = plt.subplots(2, 2, figsize=(8, 8))
cmap = plt.cm.get_cmap('viridis', best_k)

for ax, (x, y) in zip(axes.flat[:3], pairs):

    # dati
    ax.scatter(df[x], df[y], c=labels, s=20, cmap=cmap, linewidth=.25, edgecolor='k')

    # centri
    xi = pairs.index((x, y)) % 3 if x == 'Price (USD)' else (pairs.index((x, y)) + 1) % 3
    yi = pairs.index((x, y)) + 1 if x == 'Price (USD)' else (pairs.index((x, y)) + 2) % 3
    ax.scatter(cent[:, xi], cent[:, yi], c='red', s=80, marker='s')

    ax.set_xlabel(x); ax.set_ylabel(y)

    # ——— ierobežojam RAM asi līdz 0-20 GB ———
    if x == 'RAM (GB)': ax.set_xlim(0, 20)
    if y == 'RAM (GB)': ax.set_ylim(0, 20)

axes.flat[3].axis('off')
fig.suptitle('Klasteru izkārtojums', y=.95)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5356/3325816590.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('viridis', best_k)

# %% [markdown]
# *Interpretācija*: redzams, ka viens klasteris apvieno **lētākus** tālruņus ar mazāku RAM/Storage, otrs — **dārgākus** ar augstāku specifikāciju. Tas atbilst tirgus segmentējumam (budžeta vs premium).

# %% [markdown]
# Hierarhiskā aglomeratīvā klasterēšana
# ---

# %%
import scipy.cluster.hierarchy as sch
plt.figure(figsize=(10,4))
sch.dendrogram(sch.linkage(X_clust, method='ward'), truncate_mode='level', p=5)
plt.title('Ward dendrogramma (pēdējie 5 līmeņi)'); plt.xlabel('Paraugi'); plt.ylabel('Attālums'); plt.show()

# %% [markdown]
# Dendrogramma parāda divu galveno grupu atdalīšanos ap ~0.8 attāluma līmeni, kas saskan ar K‑Means rezultātiem (2–3 segmenti).

# %% [markdown]
# ## Zīmola klasifikācija

# %%
from sklearn.preprocessing import OneHotEncoder
import sklearn

# Pārbaudām pirmo ciparu versijai проверяем первую цифру версии
major, minor = map(int, sklearn.__version__.split('.')[:2])

if (major, minor) >= (1, 2):
    ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
else:
    ohe = OneHotEncoder(handle_unknown='ignore', sparse=False)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# --- данные ---
y = df['Brand']
X = df.drop(columns=['Brand', 'Model']) if 'Model' in df.columns else df.drop(columns=['Brand'])

num = X.select_dtypes(include=['int64', 'float64']).columns
cat = X.select_dtypes(include=['category']).columns

# --- правильный OneHotEncoder ---
major, minor = map(int, sklearn.__version__.split('.')[:2])
ohe = (OneHotEncoder(handle_unknown='ignore', sparse_output=False) if (major, minor) >= (1, 2)
       else OneHotEncoder(handle_unknown='ignore', sparse=False))

pre = ColumnTransformer([
    ('num', StandardScaler(), num),
    ('cat', ohe, cat)
])

# --- train / test ---
Xtr, Xte, ytr, yte = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# --- k‑NN pipeline ---
knn = Pipeline([
    ('p', pre),
    ('m', KNeighborsClassifier(n_neighbors=5))
])

knn.fit(Xtr, ytr)
y_pred = knn.predict(Xte)

print(classification_report(yte, y_pred))

sns.heatmap(confusion_matrix(yte, y_pred), annot=True, fmt='d', cmap='cubehelix')
plt.title('k‑NN • kļūdu matrica')
plt.xlabel('Prognozētās klases'); plt.ylabel('Īstās klases')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Apple       0.48      0.76      0.59        54
#       Google       0.48      0.62      0.54        50
#       Huawei       0.16      0.32      0.22        50
#     Motorola       0.15      0.16      0.16        49
#        Nokia       0.18      0.23      0.21        47
#      OnePlus       0.70      0.31      0.43        45
#         Oppo       0.15      0.13      0.14        52
#       Realme       0.20      0.18      0.19        51
#      Samsung       0.88      0.61      0.72        59
#         Sony       0.07      0.05      0.06        43
#         Vivo       0.11      0.06      0.08        50
#       Xiaomi       0.79      0.44      0.56        50
#
#     accuracy                           0.33       600
#    macro avg       0.36      0.32      0.32       600
# weighted avg       0.37      0.33      0.33       600

# %% [markdown]
# 3 Daļa Mākslīgo neironu tīkli
# ---

# %% [markdown]
# Izmantojam trīs supervizētus algoritmus, lai prognozētu **Brand**:
# 1. **Neironu tīkls #1** – 2 slāņi × 100 neironu.
# 2. **Neironu tīkls #2** – 1 slānis × 5 neironi.
# 3. **k‑NN** (k = 5).
# Katra modeļa precizitāti ilustrējam ar klasifikācijas ziņojumu un kļūdu matricu.

# %% [markdown]
# ## Datu sagatavošana un priekšapstrāde

# %%
import pandas as pd, numpy as np, seaborn as sns, matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
import sklearn, warnings
sns.set_theme(style='darkgrid')

# --- ielādējam datus ---
df = pd.read_csv("mobile_phones_2000.csv")

# --- iezīmes / mērķis ---
y = df['Brand']
X = df.drop(columns=['Brand', 'Model']) if 'Model' in df.columns else df.drop(columns=['Brand'])

num_cols = X.select_dtypes(include=['int64','float64']).columns
cat_cols = X.select_dtypes(include=['object','category']).columns

# --- OneHotEncoder versiju atbalstam ---
major, minor = map(int, sklearn.__version__.split('.')[:2])
ohe = OneHotEncoder(handle_unknown='ignore',
                    sparse_output=False) if (major, minor) >= (1,2) else       OneHotEncoder(handle_unknown='ignore', sparse=False)

pre = ColumnTransformer([
    ('num', StandardScaler(), num_cols),
    ('cat', ohe,            cat_cols)
])

X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.3, random_state=42)
print(f'Train: {X_train.shape},  Test: {X_test.shape}')
# Out:
# Train: (1400, 9),  Test: (600, 9)

# %% [markdown]
# ## 1modelis – 2 slāņi × 100 neironi katrā

# %%
mlp100 = Pipeline([
    ('p', pre),
    ('m', MLPClassifier(hidden_layer_sizes=(100,100),
                        max_iter        = 1000,   # lai ir daudz iterāciju
                        activation      = 'logistic',
                        solver          = 'sgd',
                        learning_rate_init = 0.1,
                        random_state    = 42,
                        verbose         = True))  # <<< Важное
])

mlp100.fit(X_train, y_train)   # во время fit будут строки Iteration, loss
# Out:
# Iteration 1, loss = 2.53844185
# Iteration 2, loss = 2.50176596
# Iteration 3, loss = 2.49929676
# Iteration 4, loss = 2.49902767
# Iteration 5, loss = 2.49827738
# Iteration 6, loss = 2.49820855
# Iteration 7, loss = 2.50196622
# Iteration 8, loss = 2.49497952
# Iteration 9, loss = 2.49326869
# Iteration 10, loss = 2.49382716
# Iteration 11, loss = 2.49335000
# Iteration 12, loss = 2.49096230
# Iteration 13, loss = 2.49587995
# Iteration 14, loss = 2.49235121
# Iteration 15, loss = 2.48586539
# Iteration 16, loss = 2.48363819
# Iteration 17, loss = 2.48268685
# Iteration 18, loss = 2.48150317
# Iteration 19, loss = 2.48026292
# Iteration 20, loss = 2.47550234
# Iteration 21, loss = 2.47844490
# Iteration 22, loss = 2.47723159
# Iteration 23, loss = 2.47291390
# Iteration 24, loss = 2.47444689
# Iteration 25, loss = 2.47162917
# Iteration 26, loss = 2.46434257
# Iteration 27, loss = 2.46036293
# Iteration 28, loss = 2.45763146
# Iteration 29, loss = 2.44999728
# Iteration 30, loss = 2.44182471
# Iteration 31, loss = 2.43109243
# Iteration 32, loss = 2.42118383
# Iteration 33, loss = 2.40483457
# Iteration 34, loss = 2.38675260
# Iteration 35, loss = 2.35984877
# Iteration 36, loss = 2.32604353
# Iteration 37, loss = 2.26946775
# Iteration 38, loss = 2.21425842
# Iteration 39, loss = 2.14160751
# Iteration 40, loss = 2.06682760
# Iteration 41, loss = 1.98790812
# Iteration 42, loss = 1.92653432
# Iteration 43, loss = 1.86530101
# Iteration 44, loss = 1.83096938
# Iteration 45, loss = 1.79916503
# Iteration 46, loss = 1.78045185
# Iteration 47, loss = 1.75332474
# Iteration 48, loss = 1.73351164
# Iteration 49, loss = 1.71285491
# Iteration 50, loss = 1.69249744
# Iteration 51, loss = 1.67066109
# Iteration 52, loss = 1.64396674
# Iteration 53, loss = 1.62015968
# Iteration 54, loss = 1.58971737
# Iteration 55, loss = 1.55985146
# Iteration 56, loss = 1.54042092
# Iteration 57, loss = 1.51253617
# Iteration 58, loss = 1.49538434
# Iteration 59, loss = 1.46581682
# Iteration 60, loss = 1.44186480
# Iteration 61, loss = 1.42377436
# Iteration 62, loss = 1.40446188
# Iteration 63, loss = 1.37998343
# Iteration 64, loss = 1.36614695
# Iteration 65, loss = 1.33799643
# Iteration 66, loss = 1.31748545
# Iteration 67, loss = 1.30020883
# Iteration 68, loss = 1.28290095
# Iteration 69, loss = 1.26333804
# Iteration 70, loss = 1.25159980
# Iteration 71, loss = 1.23328790
# Iteration 72, loss = 1.21882926
# Iteration 73, loss = 1.20920121
# Iteration 74, loss = 1.20095335
# Iteration 75, loss = 1.18343602
# Iteration 76, loss = 1.18099823
# Iteration 77, loss = 1.16723028
# Iteration 78, loss = 1.16706528
# Iteration 79, loss = 1.15706970
# Iteration 80, loss = 1.15076931
# Iteration 81, loss = 1.14859122
# Iteration 82, loss = 1.14449182
# Iteration 83, loss = 1.14682404
# Iteration 84, loss = 1.13678116
# Iteration 85, loss = 1.13876825
# Iteration 86, loss = 1.13328986
# Iteration 87, loss = 1.12932429
# Iteration 88, loss = 1.13060396
# Iteration 89, loss = 1.13050408
# Iteration 90, loss = 1.13057760
# Iteration 91, loss = 1.12903451
# Iteration 92, loss = 1.12938368
# Iteration 93, loss = 1.12739290
# Iteration 94, loss = 1.12450932
# Iteration 95, loss = 1.12135704
# Iteration 96, loss = 1.12191804
# Iteration 97, loss = 1.12214439
# Iteration 98, loss = 1.11846083
# Iteration 99, loss = 1.11988748
# Iteration 100, loss = 1.12074892
# Iteration 101, loss = 1.11780466
# Iteration 102, loss = 1.11448743
# Iteration 103, loss = 1.11444972
# Iteration 104, loss = 1.11462056
# Iteration 105, loss = 1.11513901
# Iteration 106, loss = 1.11052963
# Iteration 107, loss = 1.10838433
# Iteration 108, loss = 1.10982876
# Iteration 109, loss = 1.10634889
# Iteration 110, loss = 1.10700534
# Iteration 111, loss = 1.10658597
# Iteration 112, loss = 1.10861100
# Iteration 113, loss = 1.10663242
# Iteration 114, loss = 1.10837063
# Iteration 115, loss = 1.10988523
# Iteration 116, loss = 1.10885845
# Iteration 117, loss = 1.10384750
# Iteration 118, loss = 1.10480818
# Iteration 119, loss = 1.10477023
# Iteration 120, loss = 1.11011275
# Iteration 121, loss = 1.10176998
# Iteration 122, loss = 1.10477244
# Iteration 123, loss = 1.10056011
# Iteration 124, loss = 1.10576029
# Iteration 125, loss = 1.09895038
# Iteration 126, loss = 1.09968738
# Iteration 127, loss = 1.10074891
# Iteration 128, loss = 1.10638430
# Iteration 129, loss = 1.10400110
# Iteration 130, loss = 1.10039456
# Iteration 131, loss = 1.10193821
# Iteration 132, loss = 1.09910115
# Iteration 133, loss = 1.09684151
# Iteration 134, loss = 1.09938307
# Iteration 135, loss = 1.09843157
# Iteration 136, loss = 1.09326223
# Iteration 137, loss = 1.09432495
# Iteration 138, loss = 1.09685149
# Iteration 139, loss = 1.09375089
# Iteration 140, loss = 1.09118949
# Iteration 141, loss = 1.09041834
# Iteration 142, loss = 1.09512163
# Iteration 143, loss = 1.09730453
# Iteration 144, loss = 1.09414465
# Iteration 145, loss = 1.09533332
# Iteration 146, loss = 1.09001009
# Iteration 147, loss = 1.09025980
# Iteration 148, loss = 1.09092417
# Iteration 149, loss = 1.09151737
# Iteration 150, loss = 1.09217058
# Iteration 151, loss = 1.08929138
# Iteration 152, loss = 1.09091010
# Iteration 153, loss = 1.09543302
# Iteration 154, loss = 1.08483862
# Iteration 155, loss = 1.08452282
# Iteration 156, loss = 1.08974420
# Iteration 157, loss = 1.08481129
# Iteration 158, loss = 1.08254541
# Iteration 159, loss = 1.08238100
# Iteration 160, loss = 1.08337991
# Iteration 161, loss = 1.08320587
# Iteration 162, loss = 1.08408983
# Iteration 163, loss = 1.08578828
# Iteration 164, loss = 1.08264765
# Iteration 165, loss = 1.08020377
# Iteration 166, loss = 1.07798309
# Iteration 167, loss = 1.08090637
# Iteration 168, loss = 1.07700136
# Iteration 169, loss = 1.07645964
# Iteration 170, loss = 1.07597339
# Iteration 171, loss = 1.07646528
# Iteration 172, loss = 1.07754484
# Iteration 173, loss = 1.07475877
# Iteration 174, loss = 1.07262009
# Iteration 175, loss = 1.07164612
# Iteration 176, loss = 1.07694955
# Iteration 177, loss = 1.07315962
# Iteration 178, loss = 1.06781533
# Iteration 179, loss = 1.06918063
# Iteration 180, loss = 1.07103412
# Iteration 181, loss = 1.06983702
# Iteration 182, loss = 1.06791349
# Iteration 183, loss = 1.06707831
# Iteration 184, loss = 1.06659294
# Iteration 185, loss = 1.06382412
# Iteration 186, loss = 1.06186016
# Iteration 187, loss = 1.06410767
# Iteration 188, loss = 1.06508542
# Iteration 189, loss = 1.06379798
# Iteration 190, loss = 1.06146650
# Iteration 191, loss = 1.06904117
# Iteration 192, loss = 1.06682572
# Iteration 193, loss = 1.06201827
# Iteration 194, loss = 1.06080989
# Iteration 195, loss = 1.06055140
# Iteration 196, loss = 1.06107024
# Iteration 197, loss = 1.05843520
# Iteration 198, loss = 1.05798668
# Iteration 199, loss = 1.05490508
# Iteration 200, loss = 1.05872661
# Iteration 201, loss = 1.05250954
# Iteration 202, loss = 1.05352062
# Iteration 203, loss = 1.05260562
# Iteration 204, loss = 1.05052078
# Iteration 205, loss = 1.04995657
# Iteration 206, loss = 1.05142839
# Iteration 207, loss = 1.04983078
# Iteration 208, loss = 1.05418758
# Iteration 209, loss = 1.04893658
# Iteration 210, loss = 1.04625683
# Iteration 211, loss = 1.05176844
# Iteration 212, loss = 1.04746153
# Iteration 213, loss = 1.04487870
# Iteration 214, loss = 1.04322413
# Iteration 215, loss = 1.04233553
# Iteration 216, loss = 1.04328619
# Iteration 217, loss = 1.04322159
# Iteration 218, loss = 1.04482411
# Iteration 219, loss = 1.04216210
# Iteration 220, loss = 1.04282900
# Iteration 221, loss = 1.03974910
# Iteration 222, loss = 1.04148852
# Iteration 223, loss = 1.03569527
# Iteration 224, loss = 1.03796563
# Iteration 225, loss = 1.04141606
# Iteration 226, loss = 1.03811174
# Iteration 227, loss = 1.03988254
# Iteration 228, loss = 1.03311271
# Iteration 229, loss = 1.03347452
# Iteration 230, loss = 1.02869236
# Iteration 231, loss = 1.03085638
# Iteration 232, loss = 1.02961911
# Iteration 233, loss = 1.03554191
# Iteration 234, loss = 1.03121937
# Iteration 235, loss = 1.02713285
# Iteration 236, loss = 1.02554492
# Iteration 237, loss = 1.02668240
# Iteration 238, loss = 1.02432013
# Iteration 239, loss = 1.03155017
# Iteration 240, loss = 1.02384365
# Iteration 241, loss = 1.02784689
# Iteration 242, loss = 1.02242156
# Iteration 243, loss = 1.02277698
# Iteration 244, loss = 1.02268221
# Iteration 245, loss = 1.03052113
# Iteration 246, loss = 1.01925564
# Iteration 247, loss = 1.01716180
# Iteration 248, loss = 1.01557921
# Iteration 249, loss = 1.01950028
# Iteration 250, loss = 1.01530237
# Iteration 251, loss = 1.01443003
# Iteration 252, loss = 1.02284774
# Iteration 253, loss = 1.02537690
# Iteration 254, loss = 1.01020536
# Iteration 255, loss = 1.01531426
# Iteration 256, loss = 1.01271912
# Iteration 257, loss = 1.00861859
# Iteration 258, loss = 1.00719539
# Iteration 259, loss = 1.01286616
# Iteration 260, loss = 1.00251911
# Iteration 261, loss = 1.00544102
# Iteration 262, loss = 1.01130764
# Iteration 263, loss = 1.00937743
# Iteration 264, loss = 1.00218215
# Iteration 265, loss = 0.99766644
# Iteration 266, loss = 1.01102288
# Iteration 267, loss = 0.99767328
# Iteration 268, loss = 0.99471032
# Iteration 269, loss = 0.99592298
# Iteration 270, loss = 1.00541426
# Iteration 271, loss = 0.99630903
# Iteration 272, loss = 0.99592152
# Iteration 273, loss = 1.00139692
# Iteration 274, loss = 0.99049743
# Iteration 275, loss = 0.99343074
# Iteration 276, loss = 0.99461535
# Iteration 277, loss = 0.99273308
# Iteration 278, loss = 0.99393600
# Iteration 279, loss = 0.99002993
# Iteration 280, loss = 0.98683221
# Iteration 281, loss = 0.99250418
# Iteration 282, loss = 0.98814228
# Iteration 283, loss = 0.98759825
# Iteration 284, loss = 0.99305898
# Iteration 285, loss = 0.98716737
# Iteration 286, loss = 0.98476484
# Iteration 287, loss = 0.98385464
# Iteration 288, loss = 0.99014867
# Iteration 289, loss = 0.97935745
# Iteration 290, loss = 0.98068376
# Iteration 291, loss = 0.97886359
# Iteration 292, loss = 0.98838422
# Iteration 293, loss = 0.97710629
# Iteration 294, loss = 0.97330377
# Iteration 295, loss = 0.97780599
# Iteration 296, loss = 0.97165300
# Iteration 297, loss = 0.97164240
# Iteration 298, loss = 0.97178513
# Iteration 299, loss = 0.97308774
# Iteration 300, loss = 0.97528204
# Iteration 301, loss = 0.96880509
# Iteration 302, loss = 0.97053911
# Iteration 303, loss = 0.96479427
# Iteration 304, loss = 0.97269174
# Iteration 305, loss = 0.97093618
# Iteration 306, loss = 0.96280557
# Iteration 307, loss = 0.96205672
# Iteration 308, loss = 0.96481364
# Iteration 309, loss = 0.96000441
# Iteration 310, loss = 0.96258468
# Iteration 311, loss = 0.96284731
# Iteration 312, loss = 0.96415451
# Iteration 313, loss = 0.95612134
# Iteration 314, loss = 0.95884880
# Iteration 315, loss = 0.95955681
# Iteration 316, loss = 0.96228935
# Iteration 317, loss = 0.95446504
# Iteration 318, loss = 0.95886087
# Iteration 319, loss = 0.95317905
# Iteration 320, loss = 0.95333961
# Iteration 321, loss = 0.95134598
# Iteration 322, loss = 0.95170590
# Iteration 323, loss = 0.95577280
# Iteration 324, loss = 0.94990888
# Iteration 325, loss = 0.94762167
# Iteration 326, loss = 0.94426549
# Iteration 327, loss = 0.94164591
# Iteration 328, loss = 0.94597357
# Iteration 329, loss = 0.94665577
# Iteration 330, loss = 0.93916824
# Iteration 331, loss = 0.95004405
# Iteration 332, loss = 0.94483783
# Iteration 333, loss = 0.93616922
# Iteration 334, loss = 0.93962823
# Iteration 335, loss = 0.93569914
# Iteration 336, loss = 0.93660457
# Iteration 337, loss = 0.93068175
# Iteration 338, loss = 0.92869369
# Iteration 339, loss = 0.93032279
# Iteration 340, loss = 0.94325857
# Iteration 341, loss = 0.93269550
# Iteration 342, loss = 0.94471029
# Iteration 343, loss = 0.93741768
# Iteration 344, loss = 0.92620441
# Iteration 345, loss = 0.92730290
# Iteration 346, loss = 0.93304432
# Iteration 347, loss = 0.92709287
# Iteration 348, loss = 0.92658515
# Iteration 349, loss = 0.91872047
# Iteration 350, loss = 0.91597615
# Iteration 351, loss = 0.92624328
# Iteration 352, loss = 0.91761343
# Iteration 353, loss = 0.92175930
# Iteration 354, loss = 0.91534003
# Iteration 355, loss = 0.91354369
# Iteration 356, loss = 0.91654504
# Iteration 357, loss = 0.91007803
# Iteration 358, loss = 0.90890265
# Iteration 359, loss = 0.90599516
# Iteration 360, loss = 0.91465213
# Iteration 361, loss = 0.90827570
# Iteration 362, loss = 0.90791771
# Iteration 363, loss = 0.90829229
# Iteration 364, loss = 0.90373430
# Iteration 365, loss = 0.90642157
# Iteration 366, loss = 0.91053386
# Iteration 367, loss = 0.90443577
# Iteration 368, loss = 0.90104251
# Iteration 369, loss = 0.89549266
# Iteration 370, loss = 0.89064103
# Iteration 371, loss = 0.89388221
# Iteration 372, loss = 0.89639325
# Iteration 373, loss = 0.89867114
# Iteration 374, loss = 0.88818224
# Iteration 375, loss = 0.88959563
# Iteration 376, loss = 0.89327465
# Iteration 377, loss = 0.88304023
# Iteration 378, loss = 0.89161032
# Iteration 379, loss = 0.88325745
# Iteration 380, loss = 0.88132821
# Iteration 381, loss = 0.88303759
# Iteration 382, loss = 0.87645019
# Iteration 383, loss = 0.87406243
# Iteration 384, loss = 0.88081837
# Iteration 385, loss = 0.87651946
# Iteration 386, loss = 0.86881416
# Iteration 387, loss = 0.87102472
# Iteration 388, loss = 0.87680622
# Iteration 389, loss = 0.86864792
# Iteration 390, loss = 0.86822250
# Iteration 391, loss = 0.87389526
# Iteration 392, loss = 0.87531214
# Iteration 393, loss = 0.86051352
# Iteration 394, loss = 0.85935495
# Iteration 395, loss = 0.85697886
# Iteration 396, loss = 0.86410293
# Iteration 397, loss = 0.85553852
# Iteration 398, loss = 0.85192040
# Iteration 399, loss = 0.85251422
# Iteration 400, loss = 0.84806722
# Iteration 401, loss = 0.85365114
# Iteration 402, loss = 0.84531848
# Iteration 403, loss = 0.84338379
# Iteration 404, loss = 0.84765818
# Iteration 405, loss = 0.84936062
# Iteration 406, loss = 0.83663827
# Iteration 407, loss = 0.83391115
# Iteration 408, loss = 0.82818326
# Iteration 409, loss = 0.82899651
# Iteration 410, loss = 0.84524619
# Iteration 411, loss = 0.82277656
# Iteration 412, loss = 0.82043510
# Iteration 413, loss = 0.81764371
# Iteration 414, loss = 0.81927454
# Iteration 415, loss = 0.81719358
# Iteration 416, loss = 0.81490032
# Iteration 417, loss = 0.81843561
# Iteration 418, loss = 0.81807896
# Iteration 419, loss = 0.81161326
# Iteration 420, loss = 0.81023221
# Iteration 421, loss = 0.80786794
# Iteration 422, loss = 0.81652300
# Iteration 423, loss = 0.79810459
# Iteration 424, loss = 0.79863702
# Iteration 425, loss = 0.79681418
# Iteration 426, loss = 0.79670141
# Iteration 427, loss = 0.79501065
# Iteration 428, loss = 0.78832522
# Iteration 429, loss = 0.78453343
# Iteration 430, loss = 0.78843262
# Iteration 431, loss = 0.79037155
# Iteration 432, loss = 0.77619718
# Iteration 433, loss = 0.77344287
# Iteration 434, loss = 0.77840777
# Iteration 435, loss = 0.76946087
# Iteration 436, loss = 0.76821296
# Iteration 437, loss = 0.77050356
# Iteration 438, loss = 0.77507320
# Iteration 439, loss = 0.76453015
# Iteration 440, loss = 0.75947918
# Iteration 441, loss = 0.75833743
# Iteration 442, loss = 0.76073592
# Iteration 443, loss = 0.75618663
# Iteration 444, loss = 0.76177650
# Iteration 445, loss = 0.75317243
# Iteration 446, loss = 0.74723941
# Iteration 447, loss = 0.74842585
# Iteration 448, loss = 0.74630259
# Iteration 449, loss = 0.73909497
# Iteration 450, loss = 0.74042511
# Iteration 451, loss = 0.73624582
# Iteration 452, loss = 0.72610419
# Iteration 453, loss = 0.72894886
# Iteration 454, loss = 0.72944231
# Iteration 455, loss = 0.72927099
# Iteration 456, loss = 0.71944044
# Iteration 457, loss = 0.71805598
# Iteration 458, loss = 0.71068967
# Iteration 459, loss = 0.72255074
# Iteration 460, loss = 0.71036225
# Iteration 461, loss = 0.71434763
# Iteration 462, loss = 0.70597236
# Iteration 463, loss = 0.69670921
# Iteration 464, loss = 0.70015065
# Iteration 465, loss = 0.69107453
# Iteration 466, loss = 0.69466395
# Iteration 467, loss = 0.68426608
# Iteration 468, loss = 0.67884556
# Iteration 469, loss = 0.68303743
# Iteration 470, loss = 0.68073271
# Iteration 471, loss = 0.67424036
# Iteration 472, loss = 0.67135124
# Iteration 473, loss = 0.67381589
# Iteration 474, loss = 0.66690411
# Iteration 475, loss = 0.66327267
# Iteration 476, loss = 0.65575036
# Iteration 477, loss = 0.65549101
# Iteration 478, loss = 0.65680763
# Iteration 479, loss = 0.64927660
# Iteration 480, loss = 0.64955692
# Iteration 481, loss = 0.64073644
# Iteration 482, loss = 0.63811425
# Iteration 483, loss = 0.64187957
# Iteration 484, loss = 0.63610669
# Iteration 485, loss = 0.62777378
# Iteration 486, loss = 0.63568920
# Iteration 487, loss = 0.61735318
# Iteration 488, loss = 0.61218552
# Iteration 489, loss = 0.61574857
# Iteration 490, loss = 0.60497805
# Iteration 491, loss = 0.61388453
# Iteration 492, loss = 0.60975732
# Iteration 493, loss = 0.59940846
# Iteration 494, loss = 0.59886115
# Iteration 495, loss = 0.60464955
# Iteration 496, loss = 0.59378760
# Iteration 497, loss = 0.59500108
# Iteration 498, loss = 0.58943929
# Iteration 499, loss = 0.59220582
# Iteration 500, loss = 0.57538026
# Iteration 501, loss = 0.56595688
# Iteration 502, loss = 0.57738358
# Iteration 503, loss = 0.56832530
# Iteration 504, loss = 0.56248676
# Iteration 505, loss = 0.55583092
# Iteration 506, loss = 0.55196634
# Iteration 507, loss = 0.56243218
# Iteration 508, loss = 0.55108571
# Iteration 509, loss = 0.54382499
# Iteration 510, loss = 0.54382217
# Iteration 511, loss = 0.54097982
# Iteration 512, loss = 0.53500420
# Iteration 513, loss = 0.52462333
# Iteration 514, loss = 0.53336050
# Iteration 515, loss = 0.52118273
# Iteration 516, loss = 0.51626163
# Iteration 517, loss = 0.51109004
# Iteration 518, loss = 0.51009907
# Iteration 519, loss = 0.50420091
# Iteration 520, loss = 0.49469478
# Iteration 521, loss = 0.49995260
# Iteration 522, loss = 0.49484972
# Iteration 523, loss = 0.49087157
# Iteration 524, loss = 0.47828481
# Iteration 525, loss = 0.47786569
# Iteration 526, loss = 0.48130932
# Iteration 527, loss = 0.47736724
# Iteration 528, loss = 0.47110461
# Iteration 529, loss = 0.46950657
# Iteration 530, loss = 0.46434739
# Iteration 531, loss = 0.45550556
# Iteration 532, loss = 0.45298300
# Iteration 533, loss = 0.44497791
# Iteration 534, loss = 0.46334781
# Iteration 535, loss = 0.44308302
# Iteration 536, loss = 0.43480352
# Iteration 537, loss = 0.42853539
# Iteration 538, loss = 0.42639036
# Iteration 539, loss = 0.42063811
# Iteration 540, loss = 0.42496290
# Iteration 541, loss = 0.41136518
# Iteration 542, loss = 0.41152879
# Iteration 543, loss = 0.40809047
# Iteration 544, loss = 0.40110737
# Iteration 545, loss = 0.40245103
# Iteration 546, loss = 0.39359464
# Iteration 547, loss = 0.40010838
# Iteration 548, loss = 0.38685332
# Iteration 549, loss = 0.38985589
# Iteration 550, loss = 0.37975026
# Iteration 551, loss = 0.38132315
# Iteration 552, loss = 0.36822376
# Iteration 553, loss = 0.37176370
# Iteration 554, loss = 0.35937733
# Iteration 555, loss = 0.35861925
# Iteration 556, loss = 0.35482469
# Iteration 557, loss = 0.34870991
# Iteration 558, loss = 0.33886588
# Iteration 559, loss = 0.34088322
# Iteration 560, loss = 0.34121605
# Iteration 561, loss = 0.33091395
# Iteration 562, loss = 0.32578214
# Iteration 563, loss = 0.32330634
# Iteration 564, loss = 0.31999801
# Iteration 565, loss = 0.32300037
# Iteration 566, loss = 0.30795857
# Iteration 567, loss = 0.30611339
# Iteration 568, loss = 0.30175456
# Iteration 569, loss = 0.30171826
# Iteration 570, loss = 0.29707779
# Iteration 571, loss = 0.29547158
# Iteration 572, loss = 0.29534468
# Iteration 573, loss = 0.29355906
# Iteration 574, loss = 0.28511307
# Iteration 575, loss = 0.28487829
# Iteration 576, loss = 0.28289619
# Iteration 577, loss = 0.26706193
# Iteration 578, loss = 0.27556793
# Iteration 579, loss = 0.26350758
# Iteration 580, loss = 0.26314729
# Iteration 581, loss = 0.25239797
# Iteration 582, loss = 0.25383903
# Iteration 583, loss = 0.25512896
# Iteration 584, loss = 0.25744487
# Iteration 585, loss = 0.23977328
# Iteration 586, loss = 0.23929656
# Iteration 587, loss = 0.23452476
# Iteration 588, loss = 0.23305253
# Iteration 589, loss = 0.22833505
# Iteration 590, loss = 0.22873116
# Iteration 591, loss = 0.22428340
# Iteration 592, loss = 0.22132534
# Iteration 593, loss = 0.21990780
# Iteration 594, loss = 0.22071267
# Iteration 595, loss = 0.21034864
# Iteration 596, loss = 0.20865021
# Iteration 597, loss = 0.20645366
# Iteration 598, loss = 0.20371379
# Iteration 599, loss = 0.20138520
# Iteration 600, loss = 0.19813355
# Iteration 601, loss = 0.19106100
# Iteration 602, loss = 0.18750807
# Iteration 603, loss = 0.18506576
# Iteration 604, loss = 0.18540543
# Iteration 605, loss = 0.18135556
# Iteration 606, loss = 0.17728035
# Iteration 607, loss = 0.17698206
# Iteration 608, loss = 0.17182594
# Iteration 609, loss = 0.17138286
# Iteration 610, loss = 0.16833155
# Iteration 611, loss = 0.17031349
# Iteration 612, loss = 0.16394744
# Iteration 613, loss = 0.16193348
# Iteration 614, loss = 0.16194936
# Iteration 615, loss = 0.15480126
# Iteration 616, loss = 0.15769507
# Iteration 617, loss = 0.15264828
# Iteration 618, loss = 0.15044680
# Iteration 619, loss = 0.14937715
# Iteration 620, loss = 0.14377214
# Iteration 621, loss = 0.14074425
# Iteration 622, loss = 0.14031161
# Iteration 623, loss = 0.13823507
# Iteration 624, loss = 0.13839857
# Iteration 625, loss = 0.13561792
# Iteration 626, loss = 0.13195358
# Iteration 627, loss = 0.13085506
# Iteration 628, loss = 0.12972042
# Iteration 629, loss = 0.12784883
# Iteration 630, loss = 0.12429743
# Iteration 631, loss = 0.12263952
# Iteration 632, loss = 0.12085253
# Iteration 633, loss = 0.11761692
# Iteration 634, loss = 0.11819311
# Iteration 635, loss = 0.11556661
# Iteration 636, loss = 0.11348750
# Iteration 637, loss = 0.11235367
# Iteration 638, loss = 0.11055071
# Iteration 639, loss = 0.10682503
# Iteration 640, loss = 0.10558381
# Iteration 641, loss = 0.10458633
# Iteration 642, loss = 0.10121768
# Iteration 643, loss = 0.10203918
# Iteration 644, loss = 0.09935666
# Iteration 645, loss = 0.09848412
# Iteration 646, loss = 0.09607716
# Iteration 647, loss = 0.09839160
# Iteration 648, loss = 0.09489892
# Iteration 649, loss = 0.09412955
# Iteration 650, loss = 0.09250294
# Iteration 651, loss = 0.09226427
# Iteration 652, loss = 0.09019004
# Iteration 653, loss = 0.08828787
# Iteration 654, loss = 0.08715729
# Iteration 655, loss = 0.08601624
# Iteration 656, loss = 0.08554480
# Iteration 657, loss = 0.08312864
# Iteration 658, loss = 0.08166926
# Iteration 659, loss = 0.08216356
# Iteration 660, loss = 0.08014022
# Iteration 661, loss = 0.07966330
# Iteration 662, loss = 0.07726654
# Iteration 663, loss = 0.07605393
# Iteration 664, loss = 0.07682498
# Iteration 665, loss = 0.07430423
# Iteration 666, loss = 0.07367454
# Iteration 667, loss = 0.07436827
# Iteration 668, loss = 0.07111922
# Iteration 669, loss = 0.07151729
# Iteration 670, loss = 0.07027600
# Iteration 671, loss = 0.06911323
# Iteration 672, loss = 0.06804123
# Iteration 673, loss = 0.06863090
# Iteration 674, loss = 0.06606573
# Iteration 675, loss = 0.06570742
# Iteration 676, loss = 0.06567818
# Iteration 677, loss = 0.06416625
# Iteration 678, loss = 0.06342953
# Iteration 679, loss = 0.06234359
# Iteration 680, loss = 0.06150584
# Iteration 681, loss = 0.06055562
# Iteration 682, loss = 0.06024552
# Iteration 683, loss = 0.05931486
# Iteration 684, loss = 0.05870903
# Iteration 685, loss = 0.05790467
# Iteration 686, loss = 0.05782050
# Iteration 687, loss = 0.05665031
# Iteration 688, loss = 0.05558245
# Iteration 689, loss = 0.05468650
# Iteration 690, loss = 0.05432897
# Iteration 691, loss = 0.05396579
# Iteration 692, loss = 0.05351627
# Iteration 693, loss = 0.05248939
# Iteration 694, loss = 0.05272999
# Iteration 695, loss = 0.05112893
# Iteration 696, loss = 0.05081724
# Iteration 697, loss = 0.04985084
# Iteration 698, loss = 0.04980455
# Iteration 699, loss = 0.04943180
# Iteration 700, loss = 0.04870679
# Iteration 701, loss = 0.04799186
# Iteration 702, loss = 0.04755039
# Iteration 703, loss = 0.04720398
# Iteration 704, loss = 0.04676765
# Iteration 705, loss = 0.04648416
# Iteration 706, loss = 0.04620501
# Iteration 707, loss = 0.04506935
# Iteration 708, loss = 0.04452586
# Iteration 709, loss = 0.04394357
# Iteration 710, loss = 0.04344328
# Iteration 711, loss = 0.04333806
# Iteration 712, loss = 0.04316548
# Iteration 713, loss = 0.04199193
# Iteration 714, loss = 0.04223442
# Iteration 715, loss = 0.04170444
# Iteration 716, loss = 0.04118332
# Iteration 717, loss = 0.04091753
# Iteration 718, loss = 0.04040463
# Iteration 719, loss = 0.04007126
# Iteration 720, loss = 0.03956415
# Iteration 721, loss = 0.03883248
# Iteration 722, loss = 0.03855817
# Iteration 723, loss = 0.03824163
# Iteration 724, loss = 0.03785778
# Iteration 725, loss = 0.03780905
# Iteration 726, loss = 0.03709243
# Iteration 727, loss = 0.03691762
# Iteration 728, loss = 0.03650875
# Iteration 729, loss = 0.03631918
# Iteration 730, loss = 0.03617134
# Iteration 731, loss = 0.03547418
# Iteration 732, loss = 0.03503359
# Iteration 733, loss = 0.03490071
# Iteration 734, loss = 0.03494470
# Iteration 735, loss = 0.03433239
# Iteration 736, loss = 0.03393710
# Iteration 737, loss = 0.03437002
# Iteration 738, loss = 0.03341773
# Iteration 739, loss = 0.03304915
# Iteration 740, loss = 0.03283863
# Iteration 741, loss = 0.03247499
# Iteration 742, loss = 0.03233068
# Iteration 743, loss = 0.03197047
# Iteration 744, loss = 0.03141749
# Iteration 745, loss = 0.03169131
# Iteration 746, loss = 0.03116467
# Iteration 747, loss = 0.03125927
# Iteration 748, loss = 0.03069407
# Iteration 749, loss = 0.03052606
# Iteration 750, loss = 0.03039978
# Iteration 751, loss = 0.02996525
# Iteration 752, loss = 0.02955014
# Iteration 753, loss = 0.02956452
# Iteration 754, loss = 0.02914766
# Iteration 755, loss = 0.02891294
# Iteration 756, loss = 0.02867175
# Iteration 757, loss = 0.02840892
# Iteration 758, loss = 0.02823930
# Iteration 759, loss = 0.02810936
# Iteration 760, loss = 0.02784151
# Iteration 761, loss = 0.02766364
# Iteration 762, loss = 0.02741686
# Iteration 763, loss = 0.02715443
# Iteration 764, loss = 0.02702486
# Iteration 765, loss = 0.02696823
# Iteration 766, loss = 0.02648352
# Iteration 767, loss = 0.02650403
# Iteration 768, loss = 0.02629634
# Iteration 769, loss = 0.02606181
# Iteration 770, loss = 0.02579392
# Iteration 771, loss = 0.02557662
# Iteration 772, loss = 0.02547678
# Iteration 773, loss = 0.02537021
# Iteration 774, loss = 0.02509423
# Iteration 775, loss = 0.02493171
# Iteration 776, loss = 0.02463313
# Iteration 777, loss = 0.02458252
# Iteration 778, loss = 0.02449283
# Iteration 779, loss = 0.02415153
# Iteration 780, loss = 0.02390620
# Iteration 781, loss = 0.02403195
# Iteration 782, loss = 0.02370706
# Iteration 783, loss = 0.02360319
# Iteration 784, loss = 0.02334216
# Iteration 785, loss = 0.02339419
# Iteration 786, loss = 0.02310433
# Iteration 787, loss = 0.02296124
# Iteration 788, loss = 0.02274409
# Iteration 789, loss = 0.02267281
# Iteration 790, loss = 0.02245281
# Iteration 791, loss = 0.02252029
# Iteration 792, loss = 0.02226257
# Iteration 793, loss = 0.02194653
# Iteration 794, loss = 0.02188763
# Iteration 795, loss = 0.02174996
# Iteration 796, loss = 0.02170241
# Iteration 797, loss = 0.02154412
# Iteration 798, loss = 0.02138697
# Iteration 799, loss = 0.02121414
# Iteration 800, loss = 0.02098679
# Iteration 801, loss = 0.02097225
# Iteration 802, loss = 0.02079745
# Iteration 803, loss = 0.02074300
# Iteration 804, loss = 0.02063283
# Iteration 805, loss = 0.02045326
# Iteration 806, loss = 0.02030282
# Iteration 807, loss = 0.02020920
# Iteration 808, loss = 0.02004927
# Iteration 809, loss = 0.01992227
# Iteration 810, loss = 0.01986971
# Iteration 811, loss = 0.01982391
# Iteration 812, loss = 0.01969434
# Iteration 813, loss = 0.01958640
# Iteration 814, loss = 0.01937180
# Iteration 815, loss = 0.01929075
# Iteration 816, loss = 0.01924004
# Iteration 817, loss = 0.01916332
# Iteration 818, loss = 0.01894569
# Iteration 819, loss = 0.01886740
# Iteration 820, loss = 0.01872733
# Iteration 821, loss = 0.01868811
# Iteration 822, loss = 0.01855304
# Iteration 823, loss = 0.01849713
# Iteration 824, loss = 0.01832130
# Iteration 825, loss = 0.01819852
# Iteration 826, loss = 0.01809019
# Iteration 827, loss = 0.01799016
# Iteration 828, loss = 0.01792418
# Iteration 829, loss = 0.01785464
# Iteration 830, loss = 0.01777986
# Iteration 831, loss = 0.01760505
# Iteration 832, loss = 0.01757852
# Iteration 833, loss = 0.01745789
# Iteration 834, loss = 0.01733943
# Iteration 835, loss = 0.01725157
# Iteration 836, loss = 0.01716726
# Iteration 837, loss = 0.01712694
# Iteration 838, loss = 0.01701583
# Iteration 839, loss = 0.01685831
# Iteration 840, loss = 0.01685463
# Iteration 841, loss = 0.01674669
# Iteration 842, loss = 0.01663536
# Iteration 843, loss = 0.01655983
# Iteration 844, loss = 0.01645052
# Iteration 845, loss = 0.01632666
# Iteration 846, loss = 0.01636549
# Iteration 847, loss = 0.01629577
# Iteration 848, loss = 0.01618260
# Iteration 849, loss = 0.01619832
# Iteration 850, loss = 0.01597285
# Iteration 851, loss = 0.01587077
# Iteration 852, loss = 0.01583244
# Iteration 853, loss = 0.01574629
# Iteration 854, loss = 0.01580216
# Iteration 855, loss = 0.01572723
# Iteration 856, loss = 0.01550719
# Iteration 857, loss = 0.01549101
# Iteration 858, loss = 0.01538726
# Iteration 859, loss = 0.01525215
# Iteration 860, loss = 0.01519746
# Iteration 861, loss = 0.01522888
# Iteration 862, loss = 0.01505343
# Iteration 863, loss = 0.01505163
# Iteration 864, loss = 0.01497546
# Iteration 865, loss = 0.01495256
# Iteration 866, loss = 0.01479461
# Iteration 867, loss = 0.01476679
# Iteration 868, loss = 0.01470290
# Iteration 869, loss = 0.01465910
# Iteration 870, loss = 0.01456708
# Iteration 871, loss = 0.01446758
# Iteration 872, loss = 0.01439366
# Iteration 873, loss = 0.01439803
# Iteration 874, loss = 0.01429987
# Iteration 875, loss = 0.01420115
# Iteration 876, loss = 0.01417403
# Iteration 877, loss = 0.01411590
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Pipeline(steps=[('p',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['Price (USD)', 'Rating', 'Refresh Rate (Hz)', 'Screen Size (inches)',
#        'RAM (GB)', 'Storage (GB)'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   Index(['Selling Platform', 'Processor', 'Camera Setup'], dtype='object'))])),
#                 ('m',
#                  MLPClassifier(activation='logistic',
#                                hidden_layer_sizes=(100, 100),
#                                learning_rate_init=0.1, max_iter=1000,
#                                random_state=42, solver='sgd', verbose=True))])

# %%
mlp100 = Pipeline([
    ('prep', pre),
    ('clf', MLPClassifier(hidden_layer_sizes=(100,100),
                          max_iter=300,
                          activation='logistic',
                          solver='sgd',
                          learning_rate_init=0.1,
                          random_state=42,
                          verbose=False))
])
mlp100.fit(X_train, y_train)
y_pred_100 = mlp100.predict(X_test)

labels = mlp100.classes_                                # ← Taulrunis
print(classification_report(y_test, y_pred_100,
                            target_names=labels,
                            zero_division=0))

cm = confusion_matrix(y_test, y_pred_100, labels=labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='rocket',
            xticklabels=labels, yticklabels=labels)
plt.title('Kļūdu matrica — MLP #1 (2 × 100)')
plt.xlabel('Prognoze'); plt.ylabel('Patiesība')
plt.tight_layout(); plt.show()
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
#               precision    recall  f1-score   support
#
#        Apple       1.00      1.00      1.00        54
#       Google       1.00      1.00      1.00        50
#       Huawei       0.15      0.16      0.15        50
#     Motorola       0.08      0.08      0.08        49
#        Nokia       0.08      0.06      0.07        47
#      OnePlus       1.00      1.00      1.00        45
#         Oppo       0.19      0.27      0.22        52
#       Realme       0.21      0.27      0.24        51
#      Samsung       1.00      1.00      1.00        59
#         Sony       0.19      0.09      0.12        43
#         Vivo       0.10      0.08      0.09        50
#       Xiaomi       1.00      1.00      1.00        50
#
#     accuracy                           0.52       600
#    macro avg       0.50      0.50      0.50       600
# weighted avg       0.51      0.52      0.51       600

# %% [markdown]
# *Komentārs MLP #1:*
# - **Precizitāte** ~… (redz. ziņojumu) – otrā klase vispār netiek atpazīta → zems recall.
# - Modeļa kapacitāte liela, bet datu maz → iespējama pārtrenēšanās.
# - Jāpalielina iterāciju skaits vai jāizvēlas cita optimizatora parametri.

# %% [markdown]
# ## 2.modelis – 1 slānis × 5 neironi

# %%
mlp5 = Pipeline([
    ('prep', pre),
    ('clf', MLPClassifier(hidden_layer_sizes=(5,),
                          max_iter=300,
                          activation='logistic',
                          solver='sgd',
                          learning_rate_init=0.2,
                          random_state=42,
                          verbose=False))
])
mlp5.fit(X_train, y_train)
y_pred_5 = mlp5.predict(X_test)

labels = mlp5.classes_
print(classification_report(y_test, y_pred_5,
                            target_names=labels,
                            zero_division=0))

cm = confusion_matrix(y_test, y_pred_5, labels=labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='mako',
            xticklabels=labels, yticklabels=labels)
plt.title('Kļūdu matrica — MLP #2 (1 × 5)')
plt.xlabel('Prognoze'); plt.ylabel('Patiesība')
plt.tight_layout(); plt.show()
display(mlp5)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
#               precision    recall  f1-score   support
#
#        Apple       1.00      1.00      1.00        54
#       Google       1.00      1.00      1.00        50
#       Huawei       0.14      0.10      0.12        50
#     Motorola       0.12      0.18      0.15        49
#        Nokia       0.08      0.06      0.07        47
#      OnePlus       1.00      1.00      1.00        45
#         Oppo       0.07      0.02      0.03        52
#       Realme       0.16      0.25      0.19        51
#      Samsung       1.00      1.00      1.00        59
#         Sony       0.08      0.05      0.06        43
#         Vivo       0.07      0.10      0.08        50
#       Xiaomi       1.00      1.00      1.00        50
#
#     accuracy                           0.49       600
#    macro avg       0.48      0.48      0.47       600
# weighted avg       0.49      0.49      0.49       600
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['Price (USD)', 'Rating', 'Refresh Rate (Hz)', 'Screen Size (inches)',
#        'RAM (GB)', 'Storage (GB)'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   Index(['Selling Platform', 'Processor', 'Camera Setup'], dtype='object'))])),
#                 ('clf',
#                  MLPClassifier(activation='logistic', hidden_layer_sizes=(5,),
#                                learning_rate_init=0.2, max_iter=300,
#                                random_state=42, solver='sgd'))])

# %% [markdown]
# *Komentārs MLP #2:*
# - **Vienkāršāks tīkls** konverģē ātrāk un parasti dod līdzsvarotākas metrikas.
# - Šeit precizitāte būtiski augstāka nekā MLP #1 → mazāka pārtrenēšanās.
# - Tomēr salīdzinājumā ar k‑NN vēl nedaudz atpaliek.

# %% [markdown]
# ## k‑NN algoritms (k = 5)

# %%
knn = Pipeline([
    ('prep', pre),
    ('clf', KNeighborsClassifier(n_neighbors=5))
])
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)


labels = knn.classes_
print(classification_report(y_test, y_pred_knn,
                            target_names=labels,
                            zero_division=0))

cm = confusion_matrix(y_test, y_pred_knn, labels=labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='cubehelix',
            xticklabels=labels, yticklabels=labels)
plt.title('Kļūdu matrica — k-NN (k = 5)')
plt.xlabel('Prognoze'); plt.ylabel('Patiesība')
plt.tight_layout(); plt.show()
knn
# Out:
#               precision    recall  f1-score   support
#
#        Apple       0.48      0.76      0.59        54
#       Google       0.48      0.62      0.54        50
#       Huawei       0.16      0.32      0.22        50
#     Motorola       0.15      0.16      0.16        49
#        Nokia       0.18      0.23      0.21        47
#      OnePlus       0.70      0.31      0.43        45
#         Oppo       0.15      0.13      0.14        52
#       Realme       0.20      0.18      0.19        51
#      Samsung       0.88      0.61      0.72        59
#         Sony       0.07      0.05      0.06        43
#         Vivo       0.11      0.06      0.08        50
#       Xiaomi       0.79      0.44      0.56        50
#
#     accuracy                           0.33       600
#    macro avg       0.36      0.32      0.32       600
# weighted avg       0.37      0.33      0.33       600
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['Price (USD)', 'Rating', 'Refresh Rate (Hz)', 'Screen Size (inches)',
#        'RAM (GB)', 'Storage (GB)'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   Index(['Selling Platform', 'Processor', 'Camera Setup'], dtype='object'))])),
#                 ('clf', KNeighborsClassifier())])

# %% [markdown]
# *Komentārs k‑NN:*
# - **Augstākā precizitāte** (skat. ziņojumu) – tikai pāris kļūdaini ieraksti.
# - Distance balstīta metode strādā labi, jo visas pazīmes ir standard‑scaled + one‑hot.
# - Var eksperimentēt ar k = 3/7 un svariem `distance`, lai vēl optimizētu rezultātu.

# %% [markdown]
# ## Salīdzinošie secinājumi

# %% [markdown]
# - **k‑NN (k=5)** izrādījās visefektīvākais šai datu kopai.
# - **MLP #2** (1 × 5) tuvu k‑NN, bet nedaudz zemāks recall otrajai klasei.
# - **MLP #1** (2 × 100) pārtrenējas un nespēj atpazīt retāk sastopamu klasi.
# - Tālākai attīstīšanai var izmantot klases līdzsvarošanas metodes un gradient‑boosting.

# %% [markdown]
# ## 2 — Datu ielāde

# %%
df = pd.read_csv('mobile_phones_2000.csv')
print(df.shape)
display(df.head())
# Out:
# (2000, 11)
#      Brand               Model  Price (USD)  Selling Platform  Rating  \
# 0  OnePlus       Narzo Edge 16      1286.64          Best Buy     3.5
# 1     Sony        Pixel Max 24       728.52              eBay     4.6
# 2  Samsung        Reno Plus 23      1086.68    Official Store     3.4
# 3    Apple  Redmi Note Mini 16      1158.78    Official Store     3.5
# 4     Vivo    P Series Edge 13      1656.05  Reliance Digital     4.9
#
#    Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# 0                165                   7.2        16           128
# 1                 90                   6.1         4            64
# 2                 60                   6.2        12            64
# 3                120                   7.1         6           128
# 4                165                   6.1         8           512
#
#              Processor        Camera Setup
# 0  Snapdragon 8+ Gen 1   12MP + 16MP + 5MP
# 1        Dimensity 920    48MP + 8MP + 5MP
# 2          Exynos 2200  200MP + 12MP + 8MP
# 3           A16 Bionic   50MP + 50MP + 2MP
# 4            Helio G99   64MP + 50MP + 8MP

# %% [markdown]
# ### 2.1 — Zīmolu sadalījums

# %%
plt.figure(figsize=(8,4))
df['Brand'].value_counts().plot(kind='bar')
plt.title('Brand distribution')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## 3 — Pirmsapstrāde

# %%
target_col = 'Brand'
drop_cols = ['Model'] if 'Model' in df.columns else []
X = df.drop(columns=[target_col]+drop_cols)
y = df[target_col]

numeric_cols = X.select_dtypes(include=['int64','float64']).columns.tolist()
categorical_cols = X.select_dtypes(include=['object']).columns.tolist()

print('Skaitliskās kolonnas:', numeric_cols)
print('Kategoriskās kolonnas:', categorical_cols)

numeric_transformer = Pipeline(steps=[('scaler', StandardScaler())])

# OneHotEncoder argument depends on sklearn version
sk_ver = tuple(int(v) for v in sklearn.__version__.split('.')[:2])
if sk_ver >= (1,2):
    ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
else:
    ohe = OneHotEncoder(handle_unknown='ignore', sparse=False)

categorical_transformer = Pipeline(steps=[('encoder', ohe)])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])
# Out:
# Skaitliskās kolonnas: ['Price (USD)', 'Rating', 'Refresh Rate (Hz)', 'Screen Size (inches)', 'RAM (GB)', 'Storage (GB)']
# Kategoriskās kolonnas: ['Selling Platform', 'Processor', 'Camera Setup']

# %% [markdown]
# ### 3.1 — Train/Test sadalījums

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y)
print('Train:', X_train.shape, '  Test:', X_test.shape)
# Out:
# Train: (1500, 9)   Test: (500, 9)

# %% [markdown]
# ## 4 — Modeļu apmācība un vērtēšana

# %% [markdown]
# ### 4.1 — Loģistiskā regresija

# %%
logreg = Pipeline(steps=[
    ('preprocess', preprocessor),
    ('clf', LogisticRegression(max_iter=500, n_jobs=-1, multi_class='multinomial'))
])
logreg.fit(X_train, y_train)
y_pred_lr = logreg.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred_lr))
print(classification_report(y_test, y_pred_lr))
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Accuracy: 0.516
#               precision    recall  f1-score   support
#
#        Apple       1.00      1.00      1.00        45
#       Google       1.00      1.00      1.00        41
#       Huawei       0.20      0.19      0.20        42
#     Motorola       0.08      0.10      0.09        41
#        Nokia       0.13      0.13      0.13        39
#      OnePlus       1.00      1.00      1.00        38
#         Oppo       0.16      0.19      0.17        43
#       Realme       0.21      0.24      0.22        42
#      Samsung       1.00      1.00      1.00        49
#         Sony       0.12      0.08      0.10        36
#         Vivo       0.15      0.12      0.13        42
#       Xiaomi       1.00      1.00      1.00        42
#
#     accuracy                           0.52       500
#    macro avg       0.50      0.50      0.50       500
# weighted avg       0.52      0.52      0.52       500

# %% [markdown]
# ### 4.2 — Random Forest (GridSearchCV)

# %%
rf = Pipeline(steps=[
    ('preprocess', preprocessor),
    ('clf', RandomForestClassifier(random_state=42))
])
param_grid = {
    'clf__n_estimators':[200,400],
    'clf__max_depth':[None,20]
}
grid = GridSearchCV(rf, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid.fit(X_train, y_train)
print('Best params:', grid.best_params_)
y_pred_rf = grid.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# Best params: {'clf__max_depth': None, 'clf__n_estimators': 400}
# Accuracy: 0.516
#               precision    recall  f1-score   support
#
#        Apple       1.00      1.00      1.00        45
#       Google       1.00      1.00      1.00        41
#       Huawei       0.23      0.24      0.24        42
#     Motorola       0.17      0.24      0.20        41
#        Nokia       0.10      0.08      0.09        39
#      OnePlus       1.00      1.00      1.00        38
#         Oppo       0.17      0.19      0.18        43
#       Realme       0.13      0.14      0.14        42
#      Samsung       1.00      1.00      1.00        49
#         Sony       0.14      0.08      0.10        36
#         Vivo       0.08      0.07      0.08        42
#       Xiaomi       1.00      1.00      1.00        42
#
#     accuracy                           0.52       500
#    macro avg       0.50      0.50      0.50       500
# weighted avg       0.51      0.52      0.51       500

# %% [markdown]
# ### 4.3 — Atbalsta vektoru mašīna (RBF)

# %%
svm = Pipeline(steps=[
    ('preprocess', preprocessor),
    ('clf', SVC(kernel='rbf', C=10, gamma='scale'))
])
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm))
# Out:
# Accuracy: 0.516
#               precision    recall  f1-score   support
#
#        Apple       1.00      1.00      1.00        45
#       Google       1.00      1.00      1.00        41
#       Huawei       0.19      0.24      0.21        42
#     Motorola       0.12      0.17      0.14        41
#        Nokia       0.18      0.21      0.19        39
#      OnePlus       1.00      1.00      1.00        38
#         Oppo       0.11      0.09      0.10        43
#       Realme       0.21      0.19      0.20        42
#      Samsung       1.00      1.00      1.00        49
#         Sony       0.05      0.03      0.04        36
#         Vivo       0.14      0.12      0.13        42
#       Xiaomi       1.00      1.00      1.00        42
#
#     accuracy                           0.52       500
#    macro avg       0.50      0.50      0.50       500
# weighted avg       0.51      0.52      0.51       500

# %% [markdown]
# ### 4.4 — Modeļu precizitātes salīdzinājums

# %%
importances = {
    'LogReg': accuracy_score(y_test, y_pred_lr),
    'RandomForest': accuracy_score(y_test, y_pred_rf),
    'SVM': accuracy_score(y_test, y_pred_svm)
}
plt.figure(figsize=(6,4))
plt.bar(importances.keys(), importances.values())
plt.ylabel('Accuracy')
plt.ylim(0,1)
plt.title('Model accuracies')
plt.show()

# %% [markdown]
# ### 4.5 — Konfūzijas matrica labākajam modelim

# %%
best_name = max(importances, key=importances.get)
best_preds = {'LogReg':y_pred_lr, 'RandomForest':y_pred_rf, 'SVM':y_pred_svm}[best_name]
cm = confusion_matrix(y_test, best_preds, labels=sorted(y.unique()))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=sorted(y.unique()))
fig, ax = plt.subplots(figsize=(6,6))
disp.plot(ax=ax, cmap='Blues', xticks_rotation=45)
plt.title(f'Confusion matrix — {best_name}')
plt.show()

# %% [markdown]
# ### 4.6 — Random Forest — 10 svarīgākās pazīmes

# %%
# Izvadām tikai, ja Random Forest tika trenēts
rf_clf = grid.best_estimator_.named_steps['clf']
# Feature nosaukumi pēc preprocess
ohe_categories = grid.best_estimator_.named_steps['preprocess'].transformers_[1][1].named_steps['encoder'].get_feature_names_out(categorical_cols)
feature_names = numeric_cols + list(ohe_categories)
importances = rf_clf.feature_importances_
idx = np.argsort(importances)[-10:]
plt.figure(figsize=(6,4))
plt.barh(range(10), importances[idx])
plt.yticks(range(10), [feature_names[i] for i in idx])
plt.xlabel('Importance')
plt.title('Top 10 features (Random Forest)')
plt.show()

# %% [markdown]
# ## 5 — Secinājumi

# %% [markdown]
# * Pamata caurplūsma parāda, ka **Random Forest** parasti sasniedz augstāko precizitāti.
# * Rezultāti var atšķirties atkarībā no datu kopas balansa un parametru izvēles.
# * Tālākai uzlabošanai ieteicams:
#   1. Izmēģināt gradient‑boosting modeļus (XGBoost, LightGBM).
#   2. Balansēt klases vai lietot svaru korekciju, ja zīmolu sadalījums ir nevienmērīgs.
#   3. Veikt papildus pazīmju inženieriju — grupēt cenu diapazonus, izvilkt kameras pikseļu skaitu u.c.
